# %% [markdown]
# ## Matplotlib 범례 표시하기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "Price ($)") #범례를 쓰기는 여기에 씀
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend() # matplotlib.pyplot에서 legend() 함수를 호출해야 위에 썼던 범례 호출됨
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "Price ($)")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# plt.legend(loc = (0.0, 0.0))
plt.legend(loc = (0.5, 0.5)) # 범례 위치지정하기
# plt.legend(loc = (1.0, 1.0))
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "Price($)")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend(loc = "lower right") # 범례 위치지정해주는 다른 방법
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "Price($)")
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label = "Demand(#)")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# plt.legend(loc = "best")
plt.legend(loc = "best", ncol = 2) # 범례의 열 개수를 지정해서 가로로 써줌
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "Price($)")
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label = "Demand(#)")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# plt.legend(loc = "best")
plt.legend(loc = "best", ncol = 2, fontsize = 14) # 범례 폰트 지정
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5,10], label = "Price($)")
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label = "Demand(#)")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# plt.legend(loc = "best")
plt.legend(loc = "best", ncol = 2, fontsize = 14, frameon = True, shadow = True) # 범례 테두리 상자유무, 그림자 유무
plt.show()
