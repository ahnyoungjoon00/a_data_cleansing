# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, "o-")
plt.title("1st Graph")
plt.ylabel("Demped oscillation")

plt.subplot(2, 1, 2)
plt.plot(x2, y2, ".-")
plt.title("2nd Graph")
plt.xlabel("time (s)")
plt.ylabel("Undamped")

plt.tight_layout()
# plt.show() # 이상하게 show()를 하고나면 이미지파일 저장이 깨짐
plt.savefig("savefig_default.png") #이미지 저장

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, "o-")
plt.title("1st Graph")
plt.ylabel("Demped oscillation")

plt.subplot(2, 1, 2)
plt.plot(x2, y2, ".-")
plt.title("2nd Graph")
plt.xlabel("time (s)")
plt.ylabel("Undamped")

plt.tight_layout()
# plt.show() # 이상하게 show()를 하고나면 이미지파일 저장이 깨짐
plt.savefig("savefig_default.png") #이미지 저장

plt.savefig("savefig_default.png") #default 는 100이다
plt.savefig("savefig_50dpi.png", dpi = 50)
plt.savefig("savefig_200dpi.png", dpi = 200) # 저장되는 사진 사이즈 얘기하는거다

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, "o-")
plt.title("1st Graph")
plt.ylabel("Demped oscillation")

plt.subplot(2, 1, 2)
plt.plot(x2, y2, ".-")
plt.title("2nd Graph")
plt.xlabel("time (s)")
plt.ylabel("Undamped")

plt.tight_layout()
# plt.show() # 이상하게 show()를 하고나면 이미지파일 저장이 깨짐
plt.savefig("savefig_facecolor.png", facecolor = "#eeeeee") # 배경색 설정하는거다

# %%
plt.figure(linewidth = 2)

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

# plt.show()
plt.savefig("savefig_edgecolor.png", facecolor = "#eeeeee", edgecolor = "blue")
# 이미지 테두리선의 색상

# %%
plt.figure(linewidth = 2)

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.savefig("savefig_bbox_inches.png", facecolor = "#eeeeee")
plt.savefig("savefig_bbox_inches2.png", facecolor = "#eeeeee", bbox_inches = "tight")
# 그래프로 저장할 영역을 설정, default는 None이고 "tight"로 지정하면 여백 최소화

# %%
plt.figure(linewidth = 2)

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.savefig("savefig_pad_inches.png", facecolor = "#eeeeee",
           bbox_inches = "tight", pad_inches = 0.3)
plt.savefig("savefig_pad_inches2.png", facecolor = "#eeeeee",
           bbox_inches = "tight", pad_inches = 0.5)
# pad_inches의 default는 0.1이며 bbox_inches = "tight"로 지정했을 때 사용가능
# 여백을 지정가능하다
