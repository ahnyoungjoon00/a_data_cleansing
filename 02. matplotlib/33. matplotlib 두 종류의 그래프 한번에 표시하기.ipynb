# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 기본 스카일 설정
plt.style.use("default")
plt.rcParams["figure.figsize"] = (4, 3)
plt.rcParams["font.size"] = 12
# 데이터 준비
x = np.arange(2020, 2027)
y1 = np.array([1, 3, 7, 5, 9, 7, 14])
y2 = np.array([1, 3, 5, 7, 9, 11, 13])
# 그래프 그리기
fig, ax1 = plt.subplots()

ax1.plot(x, y1, "-s", color = "green", markersize = 7, linewidth = 5, alpha = 0.7, label = "Price")
ax1.set_ylim(0, 18)
ax1.set_xlabel("Year")
ax1.set_ylabel("Price ($)")
ax1.tick_params(axis = "both", direction = "in")

ax2 = ax1.twinx()
ax2.bar(x, y2, color = "deeppink", label = "Demand", alpha =0.7, width = 0.7)
ax2.set_ylim(0, 18)
ax2.set_ylabel(r'Demand ($\times10^6$)')
ax2.tick_params(axis = "y", direction = "in")

plt.show()

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.arange(2020, 2027)
y1 = np.array([1, 3, 7, 5, 9, 7, 14])
y2 = np.array([1, 3, 5, 7, 9, 11, 13])

fig, ax1 = plt.subplots()

ax1.plot(x, y1, '-s', color='green', markersize=7, linewidth=5, alpha=0.7, label='Price')
ax1.set_ylim(0, 18)
ax1.set_xlabel('Year')
ax1.set_ylabel('Price ($)')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.bar(x, y2, color='deeppink', label='Demand', alpha=0.7, width=0.7)
ax2.set_ylim(0, 18)
ax2.set_ylabel(r'Demand ($\times10^6$)')
ax2.tick_params(axis='y', direction='in')

ax1.set_zorder(ax2.get_zorder() + 10) # 그래프 순서를 지정해서 꺾은선 그래프가 앞으로 나와 잘보임
ax1.patch.set_visible(False)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
# 범례 그리기
plt.show()
